# %%
import pandas as pd
import numpy as np
import os
import sys
import csv
import glob

# %%
# get data file names
#path =r"F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)"
#filenames = glob.glob(path + "/*.xls")
os.chdir('F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)')
listmain = os.listdir()
print(listmain)
for li in listmain:
    os.chdir(li)
    three = os.listdir() 
    #print("HELLO, AGAIN")
    for each in three:
        print(each, type(each))
        print(os.getcwd())
    
        os.chdir(each)
        if each == 'SC':            
            mini = os.listdir()
            print(mini)
            print("Inside SC!")
            for m in mini:
                os.chdir(m)
                FileList = glob.glob('*.xls')
                print(FileList)
                os.chdir('..')
        if each =='RH' or 'PHC':
            #os.chdir(each)
            FileList = glob.glob('*.xls')
            print(FileList)
            os.chdir('..')
    os.chdir('..')


# FileList = glob.glob('*.txt')
# print(FileList)
# Out:
# ['BHIWAPUR BLOCK', 'HINGNA BLOCK', 'KALMESHWAR BLOCK', 'KAMPTEE BLOCK', 'KATOL BLOCK', 'KUHI BLOCK', 'MOUDA BLOCK', 'NAGPUR BLOCK', 'NARKHED BLOCK', 'PARSHIVNI BLOCK', 'RAMTEK BLOCK', 'SAONER BLOCK', 'UMRED BLOCK']
# PHC <class 'str'>
# F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)\BHIWAPUR BLOCK
# ['Copy of MonthlyProgressReportMIES_PHC Jawali_Apr-2015.xls', 'Copy of MonthlyProgressReportMIES_PHC Nand (Nagpur)_Apr-2015.xls', 'Copy of MonthlyProgressReportMIES_PHC Somnala_Apr-2015.xls']
# RH <class 'str'>
# F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)\BHIWAPUR BLOCK
# ['Copy of MonthlyProgressReportMIES_RH Bhivpur _Apr-2015.xls']
# SC <class 'str'>
# F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)\BHIWAPUR BLOCK
# ['Jawali', 'Nand', 'Somnala']
# Inside SC!
# ...

# %%
PATH = "F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)"

# %%
result = [os.path.join(dp, f) for dp, dn, filenames in os.walk(PATH) for f in filenames if os.path.splitext(f)[1] == '.xls']

# %%
result
# Out:
# ['F:\\Xyz\\SocialCops\\DHIS (APRIL 15-MARCH 16)\\DHIS (APRIL 15-MARCH 16)\\BHIWAPUR BLOCK\\PHC\\Copy of MonthlyProgressReportMIES_PHC Jawali_Apr-2015.xls',
#  'F:\\Xyz\\SocialCops\\DHIS (APRIL 15-MARCH 16)\\DHIS (APRIL 15-MARCH 16)\\BHIWAPUR BLOCK\\PHC\\Copy of MonthlyProgressReportMIES_PHC Nand (Nagpur)_Apr-2015.xls',
#  'F:\\Xyz\\SocialCops\\DHIS (APRIL 15-MARCH 16)\\DHIS (APRIL 15-MARCH 16)\\BHIWAPUR BLOCK\\PHC\\Copy of MonthlyProgressReportMIES_PHC Somnala_Apr-2015.xls',
#  'F:\\Xyz\\SocialCops\\DHIS (APRIL 15-MARCH 16)\\DHIS (APRIL 15-MARCH 16)\\BHIWAPUR BLOCK\\RH\\Copy of MonthlyProgressReportMIES_RH Bhivpur _Apr-2015.xls',
#  'F:\\Xyz\\SocialCops\\DHIS (APRIL 15-MARCH 16)\\DHIS (APRIL 15-MARCH 16)\\BHIWAPUR BLOCK\\SC\\Jawali\\Copy of MonthlyProgressReportMIES_Dhamangaon1 SC_Apr-2015.xls',
#  'F:\\Xyz\\SocialCops\\DHIS (APRIL 15-MARCH 16)\\DHIS (APRIL 15-MARCH 16)\\BHIWAPUR BLOCK\\SC\\Jawali\\Copy of MonthlyProgressReportMIES_JAWALI SC_Apr-2015.xls',
# ...

# %%
fl = "F:\Xyz\SocialCops\DHIS (APRIL 15-MARCH 16)\DHIS (APRIL 15-MARCH 16)\BHIWAPUR BLOCK\PHC\Copy of MonthlyProgressReportMIES_PHC Jawali_Apr-2015.xls"

# %%
df = pd.read_excel(fl, 'Sheet 1', skiprows=0)

# %%
df
# Out:
#      Unnamed: 0 Monthly Progress Report  \
# 0           NaN                     NaN
# 1           NaN                Facility
# 2           NaN                     NaN
# 3           NaN                  Period
# 4           NaN                     NaN
# 5           NaN                     NaN
# 6           NaN                  Part A
# 7           NaN                      M1
# 8           NaN                     1.1
# 9           NaN                   1.1.1
# 10          NaN                     1.2
# 11          NaN                     1.3
# 12          NaN                     1.4
# 13          NaN                   1.4.1
# 14          NaN                   1.4.2
# 15          NaN                     1.5
# 16          NaN                     1.6
# 17          NaN                   1.6.1
# 18          NaN                   1.6.2
# 19          NaN                     1.7
# 20          NaN                   1.7.1
# 21          NaN                   1.7.2
# ...

# %%
df.iloc[[20]]
# Out:
#     Unnamed: 0 Monthly Progress Report  \
# 20         NaN                   1.7.1
#
#                                   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 20  Number having Hb level<11 (tested cases)      TOTAL         25         31
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 20         16         20         22         24          19          20
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 20          14          21          19          18         249
